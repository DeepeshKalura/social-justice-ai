# %%
import numpy as np
import pandas as pd

# %%
table= pd.read_csv(r"../../data/Population-by-state.csv", header= 1)
df_p=pd.DataFrame(data=table)
df_p.head(5)
# Out:
#             Id  Id2   Geography  April 1, 2010 - Census  \
# 0  0400000US01    1     Alabama                 4779736
# 1  0400000US02    2      Alaska                  710231
# 2  0400000US04    4     Arizona                 6392017
# 3  0400000US05    5    Arkansas                 2915918
# 4  0400000US06    6  California                37253956
#
#    April 1, 2010 - Estimates Base  Population Estimate (as of July 1) - 2010  \
# 0                         4780131                                    4785492
# 1                          710249                                     714031
# 2                         6392301                                    6408312
# 3                         2916025                                    2921995
# 4                        37254522                                   37332685
#
#    Population Estimate (as of July 1) - 2011  \
# 0                                    4799918
# 1                                     722713
# ...

# %%
# table= pd.read_csv(r"../../data/2007-2016-Homelessnewss-USA.csv", header= 1)
# df_h=pd.DataFrame(data=table)
# df_h.head(5)
# Out:
#    1/1/2007  AK  AK-500  Anchorage CoC  \
# 0  1/1/2007  AK  AK-500  Anchorage CoC
# 1  1/1/2007  AK  AK-500  Anchorage CoC
# 2  1/1/2007  AK  AK-500  Anchorage CoC
# 3  1/1/2007  AK  AK-500  Anchorage CoC
# 4  1/1/2007  AK  AK-500  Anchorage CoC
#
#              Chronically Homeless Individuals  224
# 0                        Homeless Individuals  696
# 1                 Homeless People in Families  278
# 2  Sheltered Chronically Homeless Individuals  187
# 3                          Sheltered Homeless  842
# 4              Sheltered Homeless Individuals  589

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86528 entries, 0 to 86527
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   1/1/2007                          86528 non-null  object
#  1   AK                                86528 non-null  object
#  2   AK-500                            86528 non-null  object
#  3   Anchorage CoC                     86528 non-null  object
#  4   Chronically Homeless Individuals  86528 non-null  object
#  5   224                               86528 non-null  object
# dtypes: object(6)
# memory usage: 4.0+ MB
#         1/1/2007     AK  AK-500                    Anchorage CoC  \
# count      86528  86528   86528                            86528
# unique        10     54     414                              414
# top     1/1/2015     CA  MN-500  Minneapolis/Hennepin County CoC
# ...

# %%
df_p.info()
df_p.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 12 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Id                                         52 non-null     object
#  1   Id2                                        52 non-null     int64
#  2   Geography                                  52 non-null     object
#  3   April 1, 2010 - Census                     52 non-null     int64
#  4   April 1, 2010 - Estimates Base             52 non-null     int64
#  5   Population Estimate (as of July 1) - 2010  52 non-null     int64
#  6   Population Estimate (as of July 1) - 2011  52 non-null     int64
#  7   Population Estimate (as of July 1) - 2012  52 non-null     int64
#  8   Population Estimate (as of July 1) - 2013  52 non-null     int64
#  9   Population Estimate (as of July 1) - 2014  52 non-null     int64
# ...

# %%
df = df_p.apply(pd.to_numeric, errors='coerce')
correlation = df.corr()

# %%
correlation
# Out:
#                                            Id       Id2  Geography  \
# Id                                        NaN       NaN        NaN
# Id2                                       NaN  1.000000        NaN
# Geography                                 NaN       NaN        NaN
# April 1, 2010 - Census                    NaN -0.091249        NaN
# April 1, 2010 - Estimates Base            NaN -0.091260        NaN
# Population Estimate (as of July 1) - 2010 NaN -0.091271        NaN
# Population Estimate (as of July 1) - 2011 NaN -0.091490        NaN
# Population Estimate (as of July 1) - 2012 NaN -0.091618        NaN
# Population Estimate (as of July 1) - 2013 NaN -0.091765        NaN
# Population Estimate (as of July 1) - 2014 NaN -0.092087        NaN
# Population Estimate (as of July 1) - 2015 NaN -0.092368        NaN
# Population Estimate (as of July 1) - 2016 NaN -0.092690        NaN
#
#                                            April 1, 2010 - Census  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(correlation, xticklabels=correlation.columns, yticklabels=correlation.columns, annot=True)
# Out:
# <Axes: >

# %%
df = df_p

# %%
l=df.sum(axis=0)
l=l[5:]
# print(l[5:])
# l[5:].max()

for year, total in l.items():
    print(f"{year[36:]}-{total}")
# Out:
#  2010-313069718
#  2011-315342090
#  2012-317632867
#  2013-319797985
#  2014-322098330
#  2015-324369799
#  2016-326538820

# %%
listofPopulation=l.to_dict()
print("Highest population year")
max(listofPopulation, key=listofPopulation.get)
# Out:
# Highest population year
# 'Population Estimate (as of July 1) - 2016'

# %%
import datetime
from datetime import datetime
years=[]
totalYears=0
for i in range(1, 86530-2):
    if(table.iloc[i, 0]!=table.iloc[i+1, 0]):
        totalYears+=1
        string= str(table.iloc[i+1, 0])
        date_time_obj = datetime.strptime(string, '%d/%m/%Y')
        #date_time_obj=  datetime.fromisoformat(table.iloc[i+1, 0])
        years.append(date_time_obj.year)
        
print("Years over which this data was collected are:")
for i in range(0, totalYears):
    print(years[i])
print("Total number of years: "+ str(totalYears))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       4 totalYears=0
#       5 for i in range(1, 86530-2):
# ----> 6     if(table.iloc[i, 0]!=table.iloc[i+1, 0]):
#       7         totalYears+=1
#       8         string= str(table.iloc[i+1, 0])
#
# NameError: name 'table' is not defined
